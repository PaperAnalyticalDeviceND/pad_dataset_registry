# %% [markdown]
# # Preprocessing FHI 2020 data

# %%
# Based on the PAD API database query notebook from Chris Sweet

# Imports
import dotenv, os
import pandas as pd

# Set env var OPENAI_API_KEY or load from a .env file:
dotenv.load_dotenv()
API_KEY=os.getenv('API_KEY') # you need to ask Chris nicely for an API key

# set url for pad server
PAD_URL = os.getenv('PAD_URL')

# %%
import grequests
import requests
from ipywidgets import interact

# Global to hold frame
df = None
jdata2 = None
r2 = None
projects = ['None']
project_ids = {'None':0}

# get cards by project
def get_cards_by_project(project):
  global df
  ret = None
  if int(project_ids[project]) > 0:
    # get cards by project
    print("loading project...")
    try:
      # sending get request and saving the response as response object
      APIURL2 = "https://pad.crc.nd.edu/api/v2/projects/{}/cards".format(project_ids[project])
      r2 = requests.get(url = APIURL2)

      # extracting data in json format
      jdata2 = r2.json()
      df = pd.DataFrame(jdata2)
      ret = f"Data loaded. Project [{project_ids[project]}]-{project} has {len(df)} cards."

    except Exception as e:
        print("API query error", e)

  return ret

# get projects

def get_projects():
  global jdata
  # get projects  - this is a one time call
  
  try:
    # sending get request and saving the response as response object
    APIURL1 = "https://pad.crc.nd.edu/api/v2/projects"
    r = requests.get(url = APIURL1)

    # extracting data in json format
    jdata = r.json()

  except Exception as e:
      print("API query error", e)

def pick_project():
  global projects
  global project_ids
  global jdata
  
  # get projects
  get_projects()
  
  # Create dropdown
  projects = ['None']
  project_ids = {'None':0}

  for i in range(0, len(jdata)):
    projects.append(jdata[i]['project_name'])
    project_ids[jdata[i]['project_name']] = jdata[i]['id']

  # widget function - do interaction to find project id and get data
  interact (get_cards_by_project, project=projects);

pick_project()
# Out:
# interactive(children=(Dropdown(description='project', options=('None', '2015-2016 USAID DIV project', '2016 PA…

# %%
## Functions
 
# Filter by sample_name column
def filter_by_sample_name(df, sample_name):
    return df[df['sample_name'].str.contains(sample_name, case=False)].copy()

# Filter by not empty and not null column_name
def filter_by_not_empty_column(df, column_name):
    if column_name not in df.columns:
        raise ValueError("The column name is not in the dataframe")
    else:
        return df[df[column_name].notnull() & (df[column_name] != "")].copy()
    
# Filter by 'unknown' column_name
def filter_by_unknown_column(df, column_name):
    if column_name not in df.columns:
        raise ValueError("The column name is not in the dataframe")
    else:
        return df[df[column_name] == "unknown"].copy()
    
# Filter by column_name and value
def filter_by_value_column(df, column_name, value):
    if column_name not in df.columns:
        raise ValueError(f"The column name {column_name} is not in the dataframe")
    else:
        return df[df[column_name] == value].copy()    

# Filter by column_name and value
def filter_by_no_value_column(df, column_name, value):
    if column_name not in df.columns:
        raise ValueError(f"The column name {column_name} is not in the dataframe")
    else:
        return df[df[column_name] != value].copy()    


def url_pad(file_location):
  return PAD_URL + str(file_location)

# %%
# Show issues
print("Deleted:")
print(df['deleted'].value_counts())

# Filter by issue
num_cards = len(df.index)
df = df[~df['deleted']]
print(f"\nFiltered {num_cards} cards to {len(df.index)} cards")
# Out:
# Deleted:
# False    9489
# True      214
# Name: deleted, dtype: int64
#
# Filtered 9703 cards to 9489 cards

# %%
# Add url to dataframe
df['url'] = df['processed_file_location'].apply(lambda x: f"https://pad.crc.nd.edu/{x}")

# %%
# Standardize the names of the samples
def standardize_names(name):
    return name.lower().replace(' ', '-')

df['sample_name'] = df['sample_name'].apply(standardize_names)
print(df.value_counts(['sample_name']).reset_index(name='counts'))
# Out:
#                    sample_name  counts
# 0           hydroxychloroquine     836
# 1                    isoniazid     532
# 2                 tetracycline     529
# 3                   rifampicin     500
# 4                ciprofloxacin     498
# 5             sulfamethoxazole     486
# 6                  ceftriaxone     480
# 7              ferrous-sulfate     465
# 8                 pyrazinamide     459
# 9                 azithromycin     446
# 10           benzyl-penicillin     446
# 11                 chloroquine     443
# 12                  ethambutol     440
# 13                        ripe     438
# 14                 epinephrine     416
# 15  promethazine-hydrochloride     411
# 16                 amoxicillin     394
# 17                 albendazole     332
# 18                  ampicillin     251
# 19                 doxycycline     247
# 20              starch-(maize)     133
# 21           calcium-carbonate     118
# 22               ascorbic-acid      83
# 23                     lactose      76
# 24                     unknown      30

# %% [markdown]
# ##  select cards that have no issues

# %%
# selct only cards with issues
issue_samples = df[df['issue'].notnull()].copy()

# selct cards that have no issues
no_issue_samples = df[df['issue'].isnull()].copy()

print(f"Total num of samples: {len(df.index)} cards")
print(f"Total num of samples with no issues: {len(no_issue_samples.index)} cards")
print(f"Total num of samples with issues: {len(issue_samples.index)} cards")
print("\nSamples by issue:")
print(issue_samples['issue'].value_counts())
# Out:
# Total num of samples: 9489 cards
# Total num of samples with no issues: 8309 cards
# Total num of samples with issues: 1180 cards
#
# Samples by issue:
# {'id': 2, 'name': 'Leak', 'description': ''}             685
# {'id': 3, 'name': 'Stuck', 'description': ''}            493
# {'id': 4, 'name': 'Rectification', 'description': ''}      2
# Name: issue, dtype: int64

# %% [markdown]
# ## Find and Remove samples with `sample_name`==`unknown`

# %%
column_name = "sample_name"

print(f"Total samples: {len(no_issue_samples.index)}")

not_empty_sample_name = filter_by_not_empty_column(no_issue_samples, column_name)
print(f"Total num of samples with empty {column_name}: " +
      f"{len(no_issue_samples.index) - len(not_empty_sample_name.index)} samples")

unknown_sample_name = filter_by_unknown_column(no_issue_samples, column_name)
print(f"Total num of samples with unknown sample_name: {len(unknown_sample_name.index)} samples")
# Out:
# Total samples: 8309
# Total num of samples with empty sample_name: 0 samples
# Total num of samples with unknown sample_name: 30 samples

# %%
import ipyplot

label_column = 'quantity'
images = unknown_sample_name['url'].values
labels = unknown_sample_name[label_column].values
labels_list_filtered = unknown_sample_name[label_column].unique().tolist()

# Show with tabs
ipyplot.plot_class_tabs(
    images, labels, tabs_order=labels_list_filtered, show_url=False,
)

# Show all
# ipyplot.plot_images(images, labels, show_url=False) # max_images=30, img_width=150)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-ZDrDq2CcXHaUhtDGnyFsdd {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ZDrDq2CcXHaUhtDGnyFsdd {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ZDrDq2CcXHaUhtDGnyFsdd {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ZDrDq2CcXHaUhtDGnyFsdd:checked ~ #ipyplot-html-viewer-textarea-ZDrDq2CcXHaUhtDGnyFsdd {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ZDrDq2CcXHaUhtDGnyFsdd:checked + #ipyplot-html-viewer-label-ZDrDq2CcXHaUhtDGnyFsdd:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-
ipyplot-content-div-SemWHFmWsXFNY25Je2h4eF-ggbYFt9VwffvmjF8PSCRZL" class="ipyplot-content-div-SemWHFmWsXFNY25Je2h4eF">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/15358_processed.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SemWHFmWsXFNY25Je2h4eF-ggbYFt9VwffvmjF8PSCRZL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SemWHFmWsXFNY25Je2h4eF">
#         <div id="ipyplot-content-div-SemWHFmWsXFNY25Je2h4eF-dUyy3e2Rd7nGZkgYy2akXn" class="ipyplot-content-div-SemWHFmWsXFNY25Je2h4eF">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/18918_processed.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SemWHFmWsXFNY25Je2h4eF-dUyy3e2Rd7nGZkgYy2akXn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SemWHFmWsXFNY25Je2h4eF">
#         <div id="ipyplot-content-div-SemWHFmWsXFNY25Je2h4eF-FGkv5tBjB8aeF23RH4QrwJ" class="ipyplot-content-div-SemWHFmWsXFNY25Je2h4eF">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>

# %%
filtered_df = no_issue_samples.copy()
filtered_df.shape
# Out:
# (8309, 16)

# %%
unknown_sample_name[['id','sample_id','sample_name','quantity','test_name','user_name','date_of_creation','url']
                    ].to_csv('./data/FHI2020_analysis/check_samples_with_unknown_sample_name.csv', index=False)

# %%
# create a Boolean mask for the rows to remove
mask = filtered_df['id'].isin(unknown_sample_name["id"].values)

# select all rows except the ones that contain `unknown`
filtered_df = filtered_df[~mask]

filtered_df.shape
# Out:
# (8279, 16)

# %% [markdown]
# ## `processed_file_location`
#
# - Checking if there are any missing and unknow values in the `processed_file_location` column

# %%
column_name = "processed_file_location"
not_empty_proc_flocation = filter_by_not_empty_column(filtered_df, column_name)
print(f"Total num of samples with empty '{column_name}': " + 
      f"{len(filtered_df.index) - len(not_empty_proc_flocation.index)} samples")

unknown_proc_flocation = filter_by_unknown_column(filtered_df, column_name)
print(f"Total num of samples with unknown '{column_name}': {len(unknown_proc_flocation.index)} samples")
# Out:
# Total num of samples with empty 'processed_file_location': 0 samples
# Total num of samples with unknown 'processed_file_location': 0 samples

# %% [markdown]
# ## Download images

# %%
#import smallutils as su
import os
from functools import partial
import numpy as np


# Change the image name pattern in this function
def create_filename(x):
    """
    Create a standardized filename based on input data.

    Args:
        x (dict): A dictionary containing information to construct the filename.

    Returns:
        str: The constructed filename in the format "{id}__{sample_name}__{quantity}".

    Example:
        input_data = {
            'id': 123,
            'sample_name': 'Acetaminphen Codeine',
            'quantity': 5
        }
        filename = create_filename(input_data)
        # Resulting filename: "123__acetaminphen-codeine__5"
    """    
    # Convert `sample_name` to lowercase and replace spaces with hyphens
    transformed_name = x['sample_name'].lower().replace(' ', '-')
    
    # Create the filename
    #fname = f"{x['id']}__{transformed_name}__{x['quantity']}__{x['image_hash']}.png"
    fname = f"{x['id']}__{x['sample_id']}__{transformed_name}__{x['quantity']}.png"
    
    return fname

USER_AGENT = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36'
headers = { 'User-Agent': USER_AGENT }


def dl_images_fr_padserver(dff, tgt_folder, job_size = 100):
    """
        Download all images from the PAD server.
        Args:
            df: dataframe with the url column.
            tgt_folder: dir at which the image is stored.
            job_size: (int) number of downloads to spawn.
 
    """

    
    def _dl_file(r, folder_dir, filename, *args, **kwargs):
        fname = os.path.join(folder_dir, filename)
        
        if r.status_code == 200:
            with open(fname, 'wb') as my_file:
                # Read by 4KB chunks
                for byte_chunk in r.iter_content(chunk_size=1024*10):
                    if byte_chunk:
                        my_file.write(byte_chunk)
                        my_file.flush()
                        os.fsync(my_file)
        r.close()

 
    do_stuff = []
    #su.create_folder(tgt_folder)
    
    for _, sample in dff.iterrows():

        #handling grequest
        action_item = grequests.get(sample.url,
                                    hooks = {'response': partial(_dl_file,
                                                                folder_dir = tgt_folder,
                                                                filename = create_filename(sample))
                                             },
                                    headers = headers,
                                    stream = True)
        do_stuff.append(action_item)
 
    return grequests.map(do_stuff, size=job_size)

tgt_folder = './data/FHI2020_analysis/images_from_PADserver/'

ret_grequests = dl_images_fr_padserver(filtered_df, tgt_folder, job_size = 100)

# %%
# filtered_df["url_status_code"] = [r.status_code for r in ret_grequests] 
no_issue_samples = False

# %% [markdown]
# - Save the status code for the url requests in a new column called `url_status_code`

# %%
url_status_code = []
for i, r in enumerate(ret_grequests):
    if r is None:
        url_status_code.append(200)
    else:
        url_status_code.append(r.status_code)

# %%
filtered_df["url_status_code"] = url_status_code

# %% [markdown]
# - Summary of the status code for the url requests

# %%
num_samples_with_processed_file = len(filtered_df[filtered_df['url_status_code']==200].index)
print(f"Total num of samples with image: {num_samples_with_processed_file} samples")

num_samples_without_processed_file = len(filtered_df[filtered_df['url_status_code']!=200].index)
print(f"Total num of samples with no image: {num_samples_without_processed_file} samples")
# Out:
# Total num of samples with image: 8279 samples
# Total num of samples with no image: 0 samples

# %% [markdown]
# - Save the samples that have a status code different from 200 in a new csv file called `check_samples_without_processed_file.csv`

# %%
filtered_df[['id','sample_id','sample_name','url']][filtered_df['url_status_code'] != 200].to_csv('./data/FHI2020_analysis/check_samples_without_processed_file.csv', index=False)

# %% [markdown]
# - Save the samples that have a status code equal 200 in a new csv file called `check_samples_with_processed_file.csv`

# %%
filtered_df[['id','sample_id','sample_name','url']][filtered_df['url_status_code'] == 200].to_csv('./data/FHI2020_analysis/check_samples_with_processed_file.csv', index=False)

# %% [markdown]
# ## `Hash`

# %%
import hashlib
import concurrent.futures
import os
        
def check_hash(sample, output_folder):
    filename = create_filename(sample)
    filepath = os.path.join(output_folder, filename)
    if os.path.exists(filepath):
        if sample['image_hash'] == hashlib.md5(open(filepath,'rb').read()).hexdigest():
            return True
        else:
            return False
    else:
        return False
    
def get_hash(sample, folder):
    filename = create_filename(sample)
    filepath = os.path.join(folder, filename)
    #print(sample['id'], sample['url_status_code'], filepath)
    if sample['url_status_code'] == 200:
        if os.path.isfile(filepath):
            hashlib_md5 = hashlib.md5(open(filepath,'rb').read()).hexdigest()
            #print(hashlib_md5)
            return hashlib_md5
        else:
            print(f"File not found {filepath}. Downloading...")
            status_code = save_image_from_url(sample, tgt_folder)
            if status_code == 200:
                hashlib_md5 = hashlib.md5(open(filepath,'rb').read()).hexdigest()
                return hashlib_md5
            else:
                print(f"Error downloading {sample['id']}. File not found {filepath}")
                return None
    else:        
        return None

def get_hash_all(df, folder):
    hash_codes = []
    with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
        future_to_url = {
            executor.submit(get_hash, sample, folder): sample for _, sample in df.iterrows()
        }
        for future in concurrent.futures.as_completed(
            future_to_url
        ):
            sample = future_to_url[future]
            try:               
                #print(sample['id'], sample['url'], sample['url_status_code'] ,future.result())
                hash_codes.append([sample['id'], sample['url_status_code'], future.result()])
                
            except Exception as exc:
                print(
                    "%r generated an exception: %s" % (sample, exc)
                )
    return hash_codes

def save_image_from_url(sample, output_folder):
    r = requests.get(sample.url)
    output_path = os.path.join(
        output_folder, create_filename(sample)
    )
    with open(output_path, "wb") as f:
        f.write(r.content)
        
    status_code = r.status_code
    r.close()
    return status_code


def delete_image(sample, folder):
    filename = create_filename(sample)
    filepath = os.path.join(folder, filename)
    print(filepath)
    if os.path.exists(filepath):
        os.remove(filepath)

# %% [markdown]
# - Calculating the hash of the processed files

# %%
hash_codes = get_hash_all(filtered_df, tgt_folder)

# %% [markdown]
# - Checking if there are any missing values in the `hash` results for url_status_code == 200

# %%
ids_to_download = [id for id, url_status_code, hash_code in hash_codes if hash_code == None and url_status_code == 200]
len(ids_to_download)
# Out:
# 0

# %% [markdown]
# - In case, for some reason(?), there are samples that have url_status_code equal to 200 but they weren't downloaded, you can try to download images that have url_status_code equal to 200 and hash equal to None again.

# %%
# filter rows based on list values
dl_images_fr_padserver(filtered_df[filtered_df['id'].isin(ids_to_download)], tgt_folder, job_size = 100)

# Then, you can calculate the hash of the images again and see if I can find the images that have hash equal to None.
hash_codes = get_hash_all(filtered_df, tgt_folder)

# %% [markdown]
# ## Finally, you can create a new column called `hashlib_md5` with the hash of the images

# %%
hash_codes_df = pd.DataFrame(hash_codes, columns=['id', 'url_status_code', 'hashlib_md5'])
hash_codes_df.drop(columns=['url_status_code'], inplace=True)
filtered_df = filtered_df.merge(hash_codes_df, on='id')

# %% [markdown]
# ### `Check if there are any samples that have the same hash`

# %%
filtered_df['url_status_code'].value_counts()
# Out:
# 200    8279
# Name: url_status_code, dtype: int64

# %%
num_samples = filtered_df['url_status_code'].isin([200]).sum()
data = filtered_df.groupby(['hashlib_md5']).size().reset_index(name='counts')
one_sample_hash = data[data['counts']==1]
two_more_sample_hash = data[data['counts']>1]

print('Summary:')
print(f"Total unique hash codes : {len(data.index)}")
print(f"Total of hash code with one sample: {len(one_sample_hash.index)}")
print(f"Total of hash code with two or more samples: {len(two_more_sample_hash.index)}")

print('')
print(f"Total of samples: {num_samples}")
print(f"Total of samples without duplicates: {len(data.index)}")
print(f"Total of samples in some duplicate case (will be deleted): {num_samples-len(data.index)}")
# Out:
# Summary:
# Total unique hash codes : 7888
# Total of hash code with one sample: 7600
# Total of hash code with two or more samples: 288
#
# Total of samples: 8279
# Total of samples without duplicates: 7888
# Total of samples in some duplicate case (will be deleted): 391

# %% [markdown]
# - Handling the samples that have the same hash
#
#     - There are two cases of duplicates:
#         - [A] Samples that have the same hash and the same value in the columns `['sample_id','sample_name', 'camera_type_1' and 'quantity']`
#         - [B] Samples that have the same hash but any different values in one or more columns `['sample_id','sample_name', 'camera_type_1' and 'quantity']`

# %%
list_dup_hash = two_more_sample_hash['hashlib_md5'].to_list()
type_A = []
type_B = []

for hash in list_dup_hash:
    print(f"Hash code: {hash}")
    data = filtered_df[filtered_df['hashlib_md5']==hash].copy()
    print(f"Total of samples before: {len(data.index)}")
    unique_samples = data.drop_duplicates(subset=['sample_id','sample_name','camera_type_1', 'quantity'], keep=False)
    print(f"Total of samples after: {len(unique_samples.index)}")
    if  len(unique_samples.index) == 0:
        # A
        print(f"A: real duplicates: {len(data.index)}")
        type_A.append(hash)
    else:
        print(f"B: Samples with issue {len(data.index)}")    
        # B
        type_B.append(hash)
    print('')
# Out:
# Hash code: 03a29e3fbec78a36d8702782808c437a
# Total of samples before: 3
# Total of samples after: 0
# A: real duplicates: 3
#
# Hash code:
# Total of samples before: 3
# Total of samples after: 0
# A: real duplicates: 3
#
# Hash code: e43f8861cfc4b3b9609c804383a4e990
# Total of samples before: 2
# Total of samples after: 2
# B: Samples with issue 2
#
# Hash code: e4a1a250a2dd701bd91129e316e08b83
# Total of samples before: 2
# Total of samples after: 0
# A: real duplicates: 2
#
# Hash code: e58547c4323db27969e5656383dae80e
# Total of samples before: 6
# Total of samples after: 0
# A: real duplicates: 6
#
# Hash code: e60395c992cb1913766e537154968d3b
# Total of samples before: 2
# Total of samples after: 0
# A: real duplicates: 2
#
# Hash code: e64132df594c5e0583e58ec254687168
# Total of samples before: 2
# Total of samples after: 0
# A: real duplicates: 2
#
# Hash code: e653c4710c0c5f477723979d60734c6d
# Total of samples before: 2
# Total of samples after: 0
# A: real duplicates: 2
#
# Hash code: e65b4bae07121515a81f9d79a0a13db1
# Total of samples before: 3
# Total of samples after: 0
# A: real duplicates: 3
#
# Hash code: e6bb7e56470cacb43c46341038c5e190
# Total of samples before: 2
# Total of samples after: 0
# A: real duplicates: 2
#
# Hash code: e84eb6f2d2d0c70f63b4ecd15c3c55c1
# Total of samples before: 2
# Total of samples after: 0
# A: real duplicates: 2
#
# Hash code: e90eeb1cd7230467723c824f45346663
# Total of samples before: 2
# Total of samples after: 2
# B: Samples with issue 2
#
# Hash code: e91e69cfbeda86bb0f71d27213c4ed8f
# Total of samples before: 2
# Total of samples after: 0
# A: real duplicates: 2
#
# Hash code: e98ff392015d21588dcc923dda9b175f
# Total of samples before: 2
# Total of samples after: 0
# A: real duplicates: 2
#
# Hash code: eaa50bc0574ef5fdeb719161b747552a
# Total of samples before: 3
# Total of samples after: 0
# A: real duplicates: 3
#
# Hash code: eb573a00ef45fb45d48534267030d0d6
# Total of samples before: 3
# Total of samples after: 0
# A: real duplicates: 3
#
# Hash code: ed98ffbfd2f534a0614916f711b63d99
# Total of samples before: 3
# Total of samples after: 0
# A: real duplicates: 3
#
# Hash code: edb74aa18f64baf6c8a0d0f9890b2585
# Total of samples before: 2
# Total of samples after: 2
# B: Samples with issue 2
#
# Hash code: eef6f0e1cca4cfae3004b85cb71a8dfd
# Total of samples before: 4
# Total of samples after: 0
# A: real duplicates: 4
#
# Hash code: efd2d8d6120269e239a0968402f76d9f
# Total of samples before: 4
# Total of samples after: 0
# A: real duplicates: 4
#
# Hash code: effb9cb89f02de00f5d6c7f80e51ba9b
# Total of samples before: 2
# Total of samples after: 2
# B: Samples with issue 2
#
# Hash code: f29b8e31ae9bfc0073b627b217df2fb1
# Total of samples before: 2
# Total of samples after: 0
# A: real duplicates: 2
#
# Hash code: f33a97f9386fa868dcb596b3c2d9ba0b
# Total of samples before: 2
# Total of samples after: 0
# A: real duplicates: 2
#
# Hash code: f363bcc562eee5fa38acd493361bcb83
# Total of samples before: 2
# Total of samples after: 0
# A: real duplicates: 2
#
# Hash code: f36ac4fac7850f6583edf1ae09a123a2
# Total of samples before: 2
# Total of samples after: 0
# A: real duplicates: 2
#
# Hash code: f57c52b34317488d1e4b672e61949512
# Total of samples before: 3
# Total of samples after: 0
# A: real duplicates: 3
#
# Hash code: f617fb7f660c8f8f333dc3991551441f
# Total of samples before: 3
# Total of samples after: 0
# A: real duplicates: 3
#
# Hash code: f61849f7ea941b12c43d97257dd95d85
# Total of samples before: 2
# Total of samples after: 0
# A: real duplicates: 2
#
# Hash code: f655d8396e2e7d2eae6b18f5358a5b75
# Total of samples before: 4
# Total of samples after: 0
# A: real duplicates: 4
#
# Hash code: f903385cbc821fc60e238f56ef737489
# Total of samples before: 2
# Total of samples after: 0
# A: real duplicates: 2
#
# Hash code: fa7628f2e56a511be3ee6b9c7370528b
# Total of samples before: 2
# Total of samples after: 2
# B: Samples with issue 2
#
# Hash code: fac5e9a101289d0669e7bf022ea95090
# Total of samples before: 3
# Total of samples after: 0
# A: real duplicates: 3
#
# Hash code: fb14f3600f8e96c5779a650f8c132e7d
# Total of samples before: 3
# Total of samples after: 0
# A: real duplicates: 3
#
# Hash code: fbdba3ac8a5facc697575849ed278766
# Total of samples before: 4
# Total of samples after: 0
# A: real duplicates: 4
#
# Hash code: fd05dd51de55e393fb1251c630f4351a
# Total of samples before: 2
# Total of samples after: 0
# A: real duplicates: 2
#
# Hash code: fe3ff2134bfe312ae6de5fc415d9acb0
# Total of samples before: 2
# Total of samples after: 0
# A: real duplicates: 2
#
# Hash code: ff679282aff5c0064c2a4f5e6e968557
# Total of samples before: 2
# Total of samples after: 0
# A: real duplicates: 2

# %%
print('Summary:')
print(f"Type A: Total hash codes with real duplicate cases: {len(type_A)}")
print(f"Type B: Total hash codes with not real duplicate cases: {len(type_B)}")
# Out:
# Summary:
# Type A: Total hash codes with real duplicate cases: 255
# Type B: Total hash codes with not real duplicate cases: 33

# %% [markdown]
# - **[A] Visualize Samples that have the same hash and the same value in the columns `['sample_id','sample_name', 'camera_type_1' and 'quantity']`**

# %%
import ipyplot 
sub_list = type_A[0:6]
data = filtered_df[filtered_df['hashlib_md5'].isin(sub_list)].copy()
label_column = 'hashlib_md5'
images = data['url'].values
labels = data[label_column].values
labels_list_filtered = data[label_column].unique().tolist()

# Show with tabs
ipyplot.plot_class_tabs(
    images, labels, tabs_order=labels_list_filtered, show_url=False,
)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-BVrJfeNTaTjaa3pQ7qDqjL {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-BVrJfeNTaTjaa3pQ7qDqjL {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-BVrJfeNTaTjaa3pQ7qDqjL {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-BVrJfeNTaTjaa3pQ7qDqjL:checked ~ #ipyplot-html-viewer-textarea-BVrJfeNTaTjaa3pQ7qDqjL {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-BVrJfeNTaTjaa3pQ7qDqjL:checked + #ipyplot-html-viewer-label-BVrJfeNTaTjaa3pQ7qDqjL:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle
://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/19886_processed.png HMD Global Nokia 2.3        50
# 21906      52147 sulfamethoxazole https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/21906_processed.png HMD Global Nokia 2.3        50
# Hash: 041faa9a3603b9ebe5e6a3182a46fcb9
#    id  sample_id  sample_name                                                                                       url   camera_type_1  quantity
# 18722      51987 tetracycline https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/18722_processed.png Google Pixel 3a       100
# 18727      51987 tetracycline https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/18727_processed.png Google Pixel 3a       100
# 18731      51987 tetracycline https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/18731_processed.png Google Pixel 3a       100
# Hash: 04cb4e5ed1500896f7f075c43d226361
#    id  sample_id    sample_name                                                                                       url camera_type_1  quantity
# 17321      52447 starch-(maize) https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/17321_processed.png BLU BLU R1 HD       100
# 18681      52447 starch-(maize) https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/18681_processed.png BLU BLU R1 HD       100
# 18688      52447 starch-(maize) https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/18688_processed.png BLU BLU R1 HD       100
# 18697      52447 starch-(maize) https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/18697_processed.png BLU BLU R1 HD       100
# Hash: 0679bab4f414a40b8550d203c2edb85c
#    id  sample_id     sample_name                                                                                       url        camera_type_1  quantity
# 23078      51772 ferrous-sulfate https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23078_processed.png HMD Global Nokia 2.3       100
# 23085      51772 ferrous-sulfate https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23085_processed.png HMD Global Nokia 2.3       100

# %%
print(f"[Type B] Total of hash codes: {len(type_B)}")
# Out:
# [Type B] Total of hash codes: 33

# %%
sub_list = type_B[0:6]
data = filtered_df[filtered_df['hashlib_md5'].isin(sub_list)].copy()
label_column = 'hashlib_md5'
images = data['url'].values
labels = data[label_column].values
labels_list_filtered = data[label_column].unique().tolist()

# Show with tabs
ipyplot.plot_class_tabs(
    images, labels, tabs_order=labels_list_filtered, show_url=False,
)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-oWzjWYXRNAaRvh8LbEhJwr {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-oWzjWYXRNAaRvh8LbEhJwr {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-oWzjWYXRNAaRvh8LbEhJwr {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-oWzjWYXRNAaRvh8LbEhJwr:checked ~ #ipyplot-html-viewer-textarea-oWzjWYXRNAaRvh8LbEhJwr {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-oWzjWYXRNAaRvh8LbEhJwr:checked + #ipyplot-html-viewer-label-oWzjWYXRNAaRvh8LbEhJwr:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-oWzjWYXRNAaRvh8LbEhJwr">
#         <label id="ipyplot-html-viewer-label-oWzjWYXRNAaRvh8LbEhJwr" for="ipyplot-html-viewer-toggle-oWzjWYXRNAaRvh8LbEhJwr">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-oWzjWYXRNAaRvh8LbEhJwr" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-bDXYTZc2EXGKy2JRseVjTh {
#                 display: none;
#             }
#             input.ipyplot-tab-bDXYTZc2EXGKy2JRseVjTh + label.ipyplot-tab-label-bDXYTZc2EXGKy2JRseVjTh {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-bDXYTZc2EXGKy2JRseVjTh:checked + label.ipyplot-tab-label-bDXYTZc2EXGKy2JRseVjTh {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-bDXYTZc2EXGKy2JRseVjTh ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-bDXYTZc2EXGKy2JRseVjTh ~ .tab {
#                 display: none
#             }
#     #tabBsufyrA7KQF8hPy3rScdqU:checked ~ .tab.contentBsufyrA7KQF8hPy3rScdqU,#tabHUBYkF2kd7Nj6ZgrNUgHiA:checked ~ .tab.contentHUBYkF2kd7Nj6ZgrNUgHiA,#tabejJ9FmR3KTAKvdcgnsD8ox:checked ~ .tab.contentejJ9FmR3KTAKvdcgnsD8ox,#tab5wTz5YgGEQBGmYeodMSKWn:checked ~ .tab.content5wTz5YgGEQBGmYeodMSKWn,#tabnbwA9YGw2QUKUE8snoaCNw:checked ~ .tab.contentnbwA9YGw2QUKUE8snoaCNw,#tabJ2utvavNbmBbDfj4A9KW3S:checked ~ .tab.contentJ2utvavNbmBbDfj4A9KW3S{ display: block; }</style><input class="ipyplot-tab-bDXYTZc2EXGKy2JRseVjTh" type="radio" name="tabs-bDXYTZc2EXGKy2JRseVjTh" id="t
/><label class="ipyplot-tab-label-bDXYTZc2EXGKy2JRseVjTh" for="tabnbwA9YGw2QUKUE8snoaCNw">2560273eb5a2d20ac9186a755ab4e529</label><input class="ipyplot-tab-bDXYTZc2EXGKy2JRseVjTh" type="radio" name="tabs-bDXYTZc2EXGKy2JRseVjTh" id="tabJ2utvavNbmBbDfj4A9KW3S"/><label class="ipyplot-tab-label-bDXYTZc2EXGKy2JRseVjTh" for="tabJ2utvavNbmBbDfj4A9KW3S">15ec81eecec67bbb65ec519382ac9d3f</label><div class="tab contentBsufyrA7KQF8hPy3rScdqU">
#         <style>
#         #ipyplot-imgs-container-div-RtAMCPFoosRCzBvX2pHLcj {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-RtAMCPFoosRCzBvX2pHLcj {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-RtAMCPFoosRCzBvX2pHLcj {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-RtAMCPFoosRCzBvX2pHLcj span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-RtAMCPFoosRCzBvX2pHLcj span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-RtAMCPFoosRCzBvX2pHLcj img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-RtAMCPFoosRCzBvX2pHLcj span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-RtAMCPFoosRCzBvX2pHLcj span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-RtAMCPFoosRCzBvX2pHLcj]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-RtAMCPFoosRCzBvX2pHLcj]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-RtAMCPFoosRCzBvX2pHLcj]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-RtAMCPFoosRCzBvX2pHLcj">
#     <div class="ipyplot-placeholder-div-RtAMCPFoosRCzBvX2pHLcj">
#         <div id="ipyplot-content-div-RtAMCPFoosRCzBvX2pHLcj-W6wnjotUfKCyFyfXSybNye" class="ipyplot-content-div-RtAMCPFoosRCzBvX2pHLcj">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23049_processed.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-RtAMCPFoosRCzBvX2pHLcj-W6wnjotUfKCyFyfXSybNye">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-RtAMCPFoosRCzBvX2pHLcj">
#         <div id="ipyplot-content-div-RtAMCPFoosRCzBvX2pHLcj-ASqxCEUsH2SnwjwhB44UQY" class="ipyplot-content-div-RtAMCPFoosRCzBvX2pHLcj">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23380_processed.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-RtAMCPFoosRCzBvX2pHLcj-ASqxCEUsH2SnwjwhB44UQY">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentHUBYkF2kd7Nj6ZgrNUgHiA">
#         <style>
#         #ipyplot-imgs-container-div-54ywMdvqkA8QsiMH5koMzE {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-54ywMdvqkA8QsiMH5koMzE {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-54ywMdvqkA8QsiMH5koMzE {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-54ywMdvqkA8QsiMH5koMzE span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-54ywMdvqkA8QsiMH5koMzE span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-54ywMdvqkA8QsiMH5koMzE img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-54ywMdvqkA8QsiMH5koMzE span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-54ywMdvqkA8QsiMH5koMzE span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-54ywMdvqkA8QsiMH5koMzE]:target {
#             transform: scale(2.5);
#             trans

# %%
# save to csv
type_B_duplicates_samples = filtered_df[filtered_df['hashlib_md5'].isin(type_B)].copy().sort_values(by='hashlib_md5')
type_B_duplicates_samples[['hashlib_md5', 'id','sample_id', 'camera_type_1', 'quantity', 'url' ]].to_csv('./data/FHI2020_analysis/check_type_B_duplicates_samples.csv', index=False)

# %%
for hash in type_B:
    
    print(f"Hash: {hash}")
    print(filtered_df[filtered_df['hashlib_md5'] == hash][['id','sample_id','sample_name','url', 'camera_type_1', 'quantity']].to_string(index=False),'\n')
# Out:
# Hash: 04b768ce938cfc8849df01df582bbe14
#    id  sample_id  sample_name                                                                                       url        camera_type_1  quantity
# 24526      55092 azithromycin https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24526_processed.png HMD Global Nokia 2.3       100
# 24775      55332 azithromycin https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24775_processed.png HMD Global Nokia 2.3        20
#
# Hash: 13444e3cb26bf97be40e39169253e14c
#    id  sample_id     sample_name                                                                                       url        camera_type_1  quantity
# 23049      52979 ferrous-sulfate https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23049_processed.png HMD Global Nokia 2.3       100
# 23380      52827 ferrous-sulfate https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23380_processed.png     samsung SM-A505F        50
#
# Hash: 15ec81eecec67bbb65ec519382ac9d3f
#    id  sample_id sample_name                                                                                       url    camera_type_1  quantity
# 25574      55209        ripe https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25574_processed.png samsung SM-A505F        50
# 25594      55214        ripe https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25594_processed.png samsung SM-A505F        50
#
# Hash: 16e04ffab81cd5103f90f24a6e7d76f0
#    id  sample_id  sample_name                                                                                       url        camera_type_1  quantity
# 24265      55025 pyrazinamide https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24265_processed.png HMD Global Nokia 2.3        80
# 24373      55172 pyrazinamide https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24373_processed.png HMD Global Nokia 2.3        80
# 24379      55172 pyrazinamide https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24379_processed.png HMD Global Nokia 2.3        80
#
# Hash: 20e14f17feea6f96c2bcf61ddb570283
#    id  sample_id  sample_name                                                                                       url        camera_type_1  quantity
# 24784      55403 azithromycin https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24784_processed.png HMD Global Nokia 2.3        50
# 24809      55341 azithromycin https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24809_processed.png HMD Global Nokia 2.3        20
#
# Hash: 2560273eb5a2d20ac9186a755ab4e529
#    id  sample_id  sample_name                                                                                       url        camera_type_1  quantity
# 24840      55464 azithromycin https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24840_processed.png HMD Global Nokia 2.3        80
# 24964      55473 azithromycin https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24964_processed.png     samsung SM-A505F        50
#
# Hash: 279b1f52cb82e0b7b950f71660a4865e
#    id  sample_id  sample_name                                                                                       url        camera_type_1  quantity
# 24193      55317 pyrazinamide https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24193_processed.png HMD Global Nokia 2.3        80
# 24218      55315 pyrazinamide https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24218_processed.png     samsung SM-A505F        50
#
# Hash: 329209b66604d5f4711d1289d13920de
#    id  sample_id sample_name                                                                                       url        camera_type_1  quantity
# 22849      52903  ethambutol https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/22849_processed.png     samsung SM-A505F        80
# 22964      52776  ethambutol https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/22964_processed.png HMD Global Nokia 2.3        80
#
# Hash: 38bcec3cf77b66fb90e99e8fb3282789
#    id  sample_id sample_name                                                                                       url        camera_type_1  quantity
# 22665      52764  ethambutol https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/22665_processed.png HMD Global Nokia 2.3        20
# 22912      52735  ethambutol https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/22912_processed.png     samsung SM-A505F        50
#
# Hash: 3d551fa52eabfabc844f257c5a1fd6d4
#    id  sample_id sample_name                                                                                       url    camera_type_1  quantity
# 25343      55042        ripe https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25343_processed.png samsung SM-A505F        80
# 25404      55380        ripe https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25404_processed.png samsung SM-A505F       100
#
# Hash: 632ccca203408131e084ff2836c1a29f
#    id  sample_id sample_name                                                                                       url        camera_type_1  quantity
# 23791      51757  rifampicin https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23791_processed.png HMD Global Nokia 2.3        50
# 23892      55148  rifampicin https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23892_processed.png HMD Global Nokia 2.3        20
#
# Hash: 63607370d09778ea79a51b387c39a0f2
#    id  sample_id sample_name                                                                                       url        camera_type_1  quantity
# 19353      52031 ceftriaxone https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/19353_processed.png     samsung SM-A505F       100
# 19533      52657 ceftriaxone https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/19533_processed.png HMD Global Nokia 2.3       100
#
# Hash: 6b244bfa8a22348499f61802d5013f5d
#    id  sample_id sample_name                                                                                       url    camera_type_1  quantity
# 25475      55069        ripe https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25475_processed.png samsung SM-A505F        20
# 25584      55327        ripe https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25584_processed.png samsung SM-A505F       100
#
# Hash: 75fa1339696254293b64874e17105865
#    id  sample_id sample_name                                                                                       url        camera_type_1  quantity
# 25314      55445        ripe https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25314_processed.png HMD Global Nokia 2.3        80
# 25566      55503        ripe https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25566_processed.png     samsung SM-A505F        20
#
# Hash: 7ac347524544182e2aeaf8082df1fb49
#    id  sample_id  sample_name                                                                                       url        camera_type_1  quantity
# 24239      55311 pyrazinamide https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24239_processed.png HMD Global Nokia 2.3        80
# 24460      55300 pyrazinamide https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24460_processed.png HMD Global Nokia 2.3        20
#
# Hash: 7cb5c64c5055f2d151b16bfbb394ab04
#    id  sample_id sample_name                                                                                       url        camera_type_1  quantity
# 25216      55371        ripe https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25216_processed.png HMD Global Nokia 2.3       100
# 25355      55445        ripe https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25355_processed.png     samsung SM-A505F        80
#
# Hash: 7d77b767ef305117cb949084c691639b
#    id  sample_id     sample_name                                                                                       url        camera_type_1  quantity
# 23058      52260 ferrous-sulfate https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23058_processed.png HMD Global Nokia 2.3        20
# 23231      52973 ferrous-sulfate https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23231_processed.png     samsung SM-A505F        80
#
# Hash: 8709e2d850d3329a63f57de8c9c8102d
#    id  sample_id sample_name                                                                                       url        camera_type_1  quantity
# 19614      52661 ceftriaxone https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/19614_processed.png HMD Global Nokia 2.3        20
# 19685      52690 ceftriaxone https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/19685_processed.png HMD Global Nokia 2.3        80
#
# Hash: 9454b47569b87b5a2cf6443cea3927be
#    id  sample_id   sample_name                                                                                       url        camera_type_1  quantity
# 24592      55379 ascorbic-acid https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24592_processed.png HMD Global Nokia 2.3       100
# 24932      55382 ascorbic-acid https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24932_processed.png HMD Global Nokia 2.3       100
#
# Hash: 9bafbe5e408adb5b2bcde47a6b73d896
#    id  sample_id sample_name                                                                                       url        camera_type_1  quantity
# 19456      52664 ceftriaxone https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/19456_processed.png     samsung SM-A505F        50
# 19583      52881 ceftriaxone https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/19583_processed.png HMD Global Nokia 2.3        20
#
# Hash: a3463354fbf5c41886a1e5b5978b3ac4
#    id  sample_id sample_name                                                                                       url        camera_type_1  quantity
# 19352      52648 ceftriaxone https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/19352_processed.png     samsung SM-A505F        50
# 19675      52025 ceftriaxone https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/19675_processed.png HMD Global Nokia 2.3       100
#
# Hash: a35c3a702613aeb751830d94379e892a
#    id  sample_id  sample_name                                                                                       url    camera_type_1  quantity
# 18437      52112 tetracycline https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/18437_processed.png  Google Pixel 3a       100
# 19113      52936 tetracycline https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/19113_processed.png samsung SM-A505F       100
#
# Hash: a5bcdb60235b9b11ad97f78d029b98df
#    id  sample_id      sample_name                                                                                       url        camera_type_1  quantity
# 19714      52645 sulfamethoxazole https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/19714_processed.png HMD Global Nokia 2.3        50
# 19725      52191 sulfamethoxazole https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/19725_processed.png     samsung SM-A505F        50
#
# Hash: b79930535365c431981422d10f53a850
#    id  sample_id     sample_name                                                                                       url        camera_type_1  quantity
# 23470      52951 ferrous-sulfate https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23470_processed.png HMD Global Nokia 2.3        50
# 23529      52971 ferrous-sulfate https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23529_processed.png HMD Global Nokia 2.3        80
#
# Hash: bb0dbd00b8fd2e90d78fd3e6f0c3c968
#    id  sample_id  sample_name                                                                                       url        camera_type_1  quantity
# 24714      55476 azithromycin https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24714_processed.png HMD Global Nokia 2.3        80
# 24735      55330 azithromycin https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24735_processed.png HMD Global Nokia 2.3        20
#
# Hash: bc01821f01f83caeecaca1d2cd6b9c32
#    id  sample_id     sample_name                                                                                       url        camera_type_1  quantity
# 23038      51804 ferrous-sulfate https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23038_processed.png HMD Global Nokia 2.3       100
# 23341      51938 ferrous-sulfate https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23341_processed.png     samsung SM-A505F       100
#
# Hash: c096f6fd6458469e978a1840463d1231
#    id  sample_id  sample_name                                                                                       url        camera_type_1  quantity
# 24738      55057 azithromycin https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24738_processed.png HMD Global Nokia 2.3        80
# 24961      55481 azithromycin https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24961_processed.png     samsung SM-A505F       100
#
# Hash: c44a7c11cf94146557d30e437559e67d
#    id  sample_id      sample_name                                                                                       url    camera_type_1  quantity
# 19806      52205 sulfamethoxazole https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/19806_processed.png samsung SM-A505F        80
# 19822      52854 sulfamethoxazole https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/19822_processed.png samsung SM-A505F        80
#
# Hash: e43f8861cfc4b3b9609c804383a4e990
#    id  sample_id  sample_name                                                                                       url   camera_type_1  quantity
# 18536      51996 tetracycline https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/18536_processed.png Google Pixel 3a        50
# 18826      52076 tetracycline https://pad.crc.nd.edu//var/www/html/images/padimages/processed/10000/18826_processed.png Google Pixel 3a        20
#
# Hash: e90eeb1cd7230467723c824f45346663
#    id  sample_id sample_name                                                                                       url    camera_type_1  quantity
# 23974      51756  rifampicin https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23974_processed.png samsung SM-A505F        50
# 24039      52609  rifampicin https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/24039_processed.png samsung SM-A505F        80
#
# Hash: edb74aa18f64baf6c8a0d0f9890b2585
#    id  sample_id sample_name                                                                                       url        camera_type_1  quantity
# 23816      52622  rifampicin https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23816_processed.png HMD Global Nokia 2.3       100
# 23947      52293  rifampicin https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23947_processed.png HMD Global Nokia 2.3       100
#
# Hash: effb9cb89f02de00f5d6c7f80e51ba9b
#    id  sample_id sample_name                                                                                       url    camera_type_1  quantity
# 23652      51791  rifampicin https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23652_processed.png samsung SM-A505F        50
# 23993      55462  rifampicin https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23993_processed.png samsung SM-A505F        20
#
# Hash: fa7628f2e56a511be3ee6b9c7370528b
#    id  sample_id sample_name                                                                                       url        camera_type_1  quantity
# 25198      55161        ripe https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25198_processed.png HMD Global Nokia 2.3       100
# 25592      55044        ripe https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/25592_processed.png     samsung SM-A505F        50

# %% [markdown]
# ## Exclude duplicates for type B from a checked spreadsheet

# %%
checked_type_B = pd.read_csv('./data/FHI2020_analysis/checked_type_B_duplicates_samples.csv')
ids = checked_type_B['id'][(checked_type_B['exclude']==True) & (~checked_type_B['id'].isnull())].astype('int64').values
mask = filtered_df['id'].isin(ids)

for _, sample in filtered_df[(mask)].iterrows():
    delete_image(sample, tgt_folder)

# keep only data from not exclude ids list by mask
data = filtered_df[(~mask)]
# Out:
# ./data/FHI2020_analysis/images_from_PADserver/18437__52112__tetracycline__100.png
# ./data/FHI2020_analysis/images_from_PADserver/18536__51996__tetracycline__50.png
# ./data/FHI2020_analysis/images_from_PADserver/19352__52648__ceftriaxone__50.png
# ./data/FHI2020_analysis/images_from_PADserver/19353__52031__ceftriaxone__100.png
# ./data/FHI2020_analysis/images_from_PADserver/19456__52664__ceftriaxone__50.png
# ./data/FHI2020_analysis/images_from_PADserver/19614__52661__ceftriaxone__20.png
# ./data/FHI2020_analysis/images_from_PADserver/19714__52645__sulfamethoxazole__50.png
# ./data/FHI2020_analysis/images_from_PADserver/19806__52205__sulfamethoxazole__80.png
# ./data/FHI2020_analysis/images_from_PADserver/22665__52764__ethambutol__20.png
# ./data/FHI2020_analysis/images_from_PADserver/22849__52903__ethambutol__80.png
# ./data/FHI2020_analysis/images_from_PADserver/23038__51804__ferrous-sulfate__100.png
# ./data/FHI2020_analysis/images_from_PADserver/23049__52979__ferrous-sulfate__100.png
# ./data/FHI2020_analysis/images_from_PADserver/23058__52260__ferrous-sulfate__20.png
# ./data/FHI2020_analysis/images_from_PADserver/23470__52951__ferrous-sulfate__50.png
# ./data/FHI2020_analysis/images_from_PADserver/23652__51791__rifampicin__50.png
# ./data/FHI2020_analysis/images_from_PADserver/23791__51757__rifampicin__50.png
# ./data/FHI2020_analysis/images_from_PADserver/23816__52622__rifampicin__100.png
# ./data/FHI2020_analysis/images_from_PADserver/23974__51756__rifampicin__50.png
# ./data/FHI2020_analysis/images_from_PADserver/24193__55317__pyrazinamide__80.png
# ./data/FHI2020_analysis/images_from_PADserver/24239__55311__pyrazinamide__80.png
# ./data/FHI2020_analysis/images_from_PADserver/24265__55025__pyrazinamide__80.png
# ./data/FHI2020_analysis/images_from_PADserver/24373__55172__pyrazinamide__80.png
# ./data/FHI2020_analysis/images_from_PADserver/24526__55092__azithromycin__100.png
# ./data/FHI2020_analysis/images_from_PADserver/24592__55379__ascorbic-acid__100.png
# ./data/FHI2020_analysis/images_from_PADserver/24714__55476__azithromycin__80.png
# ./data/FHI2020_analysis/images_from_PADserver/24738__55057__azithromycin__80.png
# ./data/FHI2020_analysis/images_from_PADserver/24784__55403__azithromycin__50.png
# ./data/FHI2020_analysis/images_from_PADserver/24840__55464__azithromycin__80.png
# ./data/FHI2020_analysis/images_from_PADserver/25198__55161__ripe__100.png
# ./data/FHI2020_analysis/images_from_PADserver/25216__55371__ripe__100.png
# ./data/FHI2020_analysis/images_from_PADserver/25314__55445__ripe__80.png
# ./data/FHI2020_analysis/images_from_PADserver/25343__55042__ripe__80.png
# ./data/FHI2020_analysis/images_from_PADserver/25475__55069__ripe__20.png
# ./data/FHI2020_analysis/images_from_PADserver/25574__55209__ripe__50.png

# %% [markdown]
# ## Exclude duplicates for type A from a checked spreadsheet

# %%
# save  filtered_df dataframe to csv
#data.to_csv('./data/FHI2020_analysis/filtered_df.csv', index=False)

# %%
import pandas as pd
# load no_issue_samples dataframe from csv
data = pd.read_csv('./data/FHI2020_analysis/filtered_df.csv')

# %%
num_samples = data['url_status_code'].isin([200]).sum()
print("num_samples ", num_samples)

data_grp = data.groupby(['hashlib_md5']).size().reset_index(name='counts')


one_sample_hash = data_grp[data_grp['counts']==1]
two_more_sample_hash = data_grp[data_grp['counts']>1]


print('Summary:')
print(f"Total unique hash codes : {len(data.index)}")
print(f"Total of hash code with one sample: {len(one_sample_hash.index)}")
print(f"Total of hash code with two or more samples: {len(two_more_sample_hash.index)}")

print('')
print(f"Total of samples: {num_samples}")
print(f"Total of samples without duplicates: {len(data_grp.index)}")
print(f"Total of samples in some duplicate case (will be deleted): {num_samples-len(data_grp.index)}")
# Out:
# num_samples  8245
# Summary:
# Total unique hash codes : 8245
# Total of hash code with one sample: 7633
# Total of hash code with two or more samples: 255
#
# Total of samples: 8245
# Total of samples without duplicates: 7888
# Total of samples in some duplicate case (will be deleted): 357

# %%
list_dup_hash = two_more_sample_hash['hashlib_md5'].to_list()
print(f"Total of Unique samples {samples_unique.shape[0]}")

samples_unique_grp = samples_unique.groupby(['sample_name']).size().reset_index(name='counts')
samples_unique_grp.sort_values(by=['counts'], ascending=False)
# Out:
# Total of Unique samples 2244
#                    sample_name  counts
# 19                  rifampicin     122
# 22            sulfamethoxazole     120
# 9                ciprofloxacin     117
# 10                 doxycycline     115
# 8                  chloroquine     113
# 15                   isoniazid     112
# 4                 azithromycin     112
# 13             ferrous-sulfate     112
# 18                pyrazinamide     111
# 1                  amoxicillin     111
# 0                  albendazole     110
# 7                  ceftriaxone     110
# 2                   ampicillin     108
# 20                        ripe     108
# 14          hydroxychloroquine     108
# 12                  ethambutol     107
# 23                tetracycline     107
# 17  promethazine-hydrochloride     102
# 11                 epinephrine     100
# 5            benzyl-penicillin      39
# 16                     lactose      25
# 6            calcium-carbonate      25
# 21              starch-(maize)      25
# 3                ascorbic-acid      25

# %%
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="darkgrid")

fig, ax = plt.subplots(figsize=(6, 8))
sns.histplot(data=samples_unique_grp.sort_values(by=['counts']), x="counts",  y="sample_name",  alpha=0.5, linewidths=.8)
plt.show()

fig, ax = plt.subplots(figsize=(6, 8))
sns.barplot(samples_unique_grp.sort_values(by=['counts']), x='counts', y="sample_name", orient="y", alpha=0.6)
plt.show()

# %%
samples_unique = data[['sample_id','sample_name','quantity']].value_counts().reset_index(name='counts')
# Out:
#       sample_id         sample_name  quantity  counts
# 0         53000  hydroxychloroquine        20      27
# 1         51730  hydroxychloroquine        20      24
# 2         51727  hydroxychloroquine        20      22
# 3         53006  hydroxychloroquine        20      21
# 4         53004  hydroxychloroquine        20      18
# ...         ...                 ...       ...     ...
# 2246      53476          ampicillin       100       1
# 2247      53475          ampicillin        80       1
# 2248      53472          ampicillin        80       1
# 2249      53430         albendazole       100       1
# 2250      57643         amoxicillin       100       1
#
# [2251 rows x 4 columns]

# %%
df2 = samples_unique[['sample_id','sample_name', 'counts']]
df1 = data[['sample_id','sample_name']].value_counts().reset_index(name='counts')

df1.shape, df2.shape, 2251 - 2244
# Out:
# ((2244, 3), (2251, 3), 7)

# %%
diff_df = df1[~df1.apply(tuple,1).isin(df2.apply(tuple,1))]
diff_df
# Out:
#       sample_id  sample_name  counts
# 85        53816  chloroquine       6
# 98        53808  chloroquine       6
# 103       53817  chloroquine       6
# 168       52159   rifampicin       5
# 562       53818  chloroquine       4
# 1340      52280   rifampicin       4
# 2003      53835  chloroquine       2

# %%
ids_error =  diff_df['sample_id'].to_list()

# %%
samples_unique[samples_unique['sample_id'].isin(ids_error)]
# Out:
#       sample_id  sample_name  quantity  counts
# 110       53808  chloroquine        20       5
# 124       53816  chloroquine        20       5
# 127       53817  chloroquine        20       5
# 1040      52159   rifampicin        80       4
# 1393      52280   rifampicin        80       3
# 1396      53818  chloroquine        20       3
# 2127      52159   rifampicin       100       1
# 2154      52280   rifampicin       100       1
# 2188      53835  chloroquine       100       1
# 2189      53835  chloroquine        80       1
# 2191      53818  chloroquine        50       1
# 2192      53817  chloroquine        50       1
# 2193      53816  chloroquine        50       1
# 2194      53808  chloroquine        50       1

# %%
df1[df1['sample_id'].isin(ids_error)]
# Out:
#       sample_id  sample_name  counts
# 85        53816  chloroquine       6
# 98        53808  chloroquine       6
# 103       53817  chloroquine       6
# 168       52159   rifampicin       5
# 562       53818  chloroquine       4
# 1340      52280   rifampicin       4
# 2003      53835  chloroquine       2

# %% [markdown]
# ### Fixing quantities

# %%
def list_url_by_camera_type(df, sample_id):
    samples = df[df['sample_id'] == sample_id]
    print(f"Sample ID: {sample_id}")
    for _,sample in samples.iterrows():
        print(f"{sample['id']}\t{sample_id}\t{sample['sample_name']}\t{sample['camera_type_1']}\t\t{sample['quantity']}\t{sample['url']}")

for id in ids_error:
    list_url_by_camera_type(data, sample_id=id) 
    show_by_camera_type(data, sample_id=id)
# Out:
# Sample ID: 53816
# 20360	53816	chloroquine	Galaxy S9		20	https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20360_processed.png
# 20376	53816	chloroquine	Galaxy S9		20	https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20376_processed.png
# 20409	53816	chloroquine	iPhone 11		20	https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20409_processed.png
# 20426	53816	chloroquine	iPhone 11		20	https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20426_processed.png
# 20438	53816	chloroquine	iPhone 11		20	https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20438_processed.png
# 20503	53816	chloroquine	iPhone 11		50	https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20503_processed.png
#     <style>
#         #ipyplot-html-viewer-toggle-9YuVRfxdNcAYqJEYfe9xPx {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-9YuVRfxdNcAYqJEYfe9xPx {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-9YuVRfxdNcAYqJEYfe9xPx {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-9YuVRfxdNcAYqJEYfe9xPx:checked ~ #ipyplot-html-viewer-textarea-9YuVRfxdNcAYqJEYfe9xPx {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-9YuVRfxdNcAYqJEYfe9xPx:checked + #ipyplot-html-viewer-label-9YuVRfxdNcAYqJEYfe9xPx:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-9YuVRfxdNcAYqJEYfe9xPx">
#         <label id="ipyplot-html-viewer-label-9YuVRfxdNcAYqJEYfe9xPx" for="ipyplot-html-viewer-toggle-9YuVRfxdNcAYqJEYfe9xPx">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-9YuVRfxdNcAYqJEYfe9xPx" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-69ZLtEUTEuwS6APom3xPxU {
#                 display: none;
#             }
#             input.ipyplot-tab-69ZLtEUTEuwS6APom3xPxU + label.ipyplot-tab-label-69ZLtEUTEuwS6APom3xPxU {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-69ZLtEUTEuwS6APom3xPxU:checked + label.ipyplot-tab-label-69ZLtEUTEuwS6APom3xPxU {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-69ZLtEUTEuwS6APom3xPxU ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-69ZLtEUTEuwS6APom3xPxU ~ .tab {
#                 display: none
#             }
#     #tabbFrruEaetb6MRkUQ5fjGVy:checked ~ .tab.contentbFrruEaetb6MRkUQ5fjGVy,#tabTsghGfufhTdZBsbKNARVGC:checked ~ .tab.contentTsghGfufhTdZBsbKNARVGC{ display: block; }</style><input class="ipyplot-tab-69ZLtEUTEuwS6APom3xPxU" type="radio" name="tabs-69ZLtEUTEuwS6APom3xPxU" id="tabbFrruEaetb6MRkUQ5fjGVy" checked /><label class="ipyplot-tab-label-69ZLtEUTEuwS6APom3xPxU" for="tabbFrruEaetb6MRkUQ5fjGVy">Galaxy S9</label><input class="ipyplot-tab-69ZLtEUTEuwS6APom3xPxU" type="radio" name="tabs-69ZLtEUTEuwS6APom3xPxU" id="tabTsghGfufhTdZBsbKNARVGC"/><label class="ipyplot-tab-label-69ZLtEUTEuwS6APom3xPxU" for="tabTsghGfufhTdZBsbKNARVGC">iPhone 11</label><div class="tab contentbFrruEaetb6MRkUQ5fjGVy">
#         <style>
#         #ipyplot-imgs-container-div-RGbWXePSXeQZkVbaPyust3 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-RGbWXePSXeQZkVbaPyust3 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-RGbWXePSXeQZkVbaPyust3 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-RGbWXePSXeQZkVbaPyust3 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-RGbWXePSXeQZkVbaPyust3 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-RGbWXePSXeQZkVbaPyust3 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-RGbWXePSXeQZkVbaPyust3 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-RGbWXePSXeQZkVbaPyust3 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-RGbWXePSXeQZkVbaPyust3]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-RGbWXePSXeQZkVbaPyust3]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-RGbWXePSXeQZkVbaPyust3]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-RGbWXePSXeQZkVbaPyust3">
#     <div class="ipyplot-placeholder-div-RGbWXePSXeQZkVbaPyust3">
#         <div id="ipyplot-content-div-RGbWXePSXeQZkVbaPyust3-5pnUFcQYRyTfVY8oxLLsFk" class="ipyplot-content-div-RGbWXePSXeQZkVbaPyust3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20360_processed.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-RGbWXePSXeQZkVbaPyust3-5pnUFcQYRyTfVY8oxLLsFk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-RGbWXePSXeQZkVbaPyust3">
#         <div id="ipyplot-content-div-RGbWXePSXeQZkVbaPyust3-aEuWxPZY7gtqeVPziTfQNn" class="ipyplot-content-div-RGbWXePSXeQZkVbaPyust3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20376_processed.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-RGbWXePSXeQZkVbaPyust3-aEuWxPZY7gtqeVPziTfQNn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentTsghGfufhTdZBsbKNARVGC">
#         <style>
#         #ipyplot-imgs-container-div-ZXM5zmg2wKneGWVV6HBD23 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ZXM5zmg2wKneGWVV6HBD23 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ZXM5zmg
# <div>
#         <style>
#             input.ipyplot-tab-69ZLtEUTEuwS6APom3xPxU {
#                 display: none;
#             }
#             input.ipyplot-tab-69ZLtEUTEuwS6APom3xPxU + label.ipyplot-tab-label-69ZLtEUTEuwS6APom3xPxU {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-69ZLtEUTEuwS6APom3xPxU:checked + label.ipyplot-tab-label-69ZLtEUTEuwS6APom3xPxU {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-69ZLtEUTEuwS6APom3xPxU ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-69ZLtEUTEuwS6APom3xPxU ~ .tab {
#                 display: none
#             }
#     #tabbFrruEaetb6MRkUQ5fjGVy:checked ~ .tab.contentbFrruEaetb6MRkUQ5fjGVy,#tabTsghGfufhTdZBsbKNARVGC:checked ~ .tab.contentTsghGfufhTdZBsbKNARVGC{ display: block; }</style><input class="ipyplot-tab-69ZLtEUTEuwS6APom3xPxU" type="radio" name="tabs-69ZLtEUTEuwS6APom3xPxU" id="tabbFrruEaetb6MRkUQ5fjGVy" checked /><label class="ipyplot-tab-label-69ZLtEUTEuwS6APom3xPxU" for="tabbFrruEaetb6MRkUQ5fjGVy">Galaxy S9</label><input class="ipyplot-tab-69ZLtEUTEuwS6APom3xPxU" type="radio" name="tabs-69ZLtEUTEuwS6APom3xPxU" id="tabTsghGfufhTdZBsbKNARVGC"/><label class="ipyplot-tab-label-69ZLtEUTEuwS6APom3xPxU" for="tabTsghGfufhTdZBsbKNARVGC">iPhone 11</label><div class="tab contentbFrruEaetb6MRkUQ5fjGVy">
#         <style>
#         #ipyplot-imgs-container-div-RGbWXePSXeQZkVbaPyust3 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-RGbWXePSXeQZkVbaPyust3 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-RGbWXePSXeQZkVbaPyust3 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-RGbWXePSXeQZkVbaPyust3 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-RGbWXePSXeQZkVbaPyust3 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-RGbWXePSXeQZkVbaPyust3 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-RGbWXePSXeQZkVbaPyust3 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-RGbWXePSXeQZkVbaPyust3 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-RGbWXePSXeQZkVbaPyust3]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-RGbWXePSXeQZkVbaPyust3]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-RGbWXePSXeQZkVbaPyust3]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-RGbWXePSXeQZkVbaPyust3">
#     <div class="ipyplot-placeholder-div-RGbWXePSXeQZkVbaPyust3">
#         <div id="ipyplot-content-div-RGbWXePSXeQZkVbaPyust3-5pnUFcQYRyTfVY8oxLLsFk" class="ipyplot-content-div-RGbWXePSXeQZkVbaPyust3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20360_processed.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-RGbWXePSXeQZkVbaPyust3-5pnUFcQYRyTfVY8oxLLsFk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-RGbWXePSXeQZkVbaPyust3">
#         <div id="ipyplot-content-div-RGbWXePSXeQZkVbaPyust3-aEuWxPZY7gtqeVPziTfQNn" class="ipyplot-content-div-RGbWXePSXeQZkVbaPyust3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20376_processed.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-RGbWXePSXeQZkVbaPyust3-aEuWxPZY7gtqeVPziTfQNn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentTsghGfufhTdZBsbKNARVGC">
#         <style>
#         #ipyplot-imgs-container-div-ZXM5zmg2wKneGWVV6HBD23 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ZXM5zmg2wKneGWVV6HBD23 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-ZXM5zmg2wKneGWVV6HBD23">
#     <div class="ipyplot-placeholder-div-ZXM5zmg2wKneGWVV6HBD23">
#         <div id="ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23-P6wx7QZtYgjzHAy7q85ZMU" class="ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20409_processed.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23-P6wx7QZtYgjzHAy7q85ZMU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ZXM5zmg2wKneGWVV6HBD23">
#         <div id="ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23-oCWH8aBojVsk7SXPHjzSuh" class="ipyplot-content-div-ZXM5zmg2wKneGWVV6HBD23">
#             <h4 sty
# Sample ID: 53808
# 20313	53808	chloroquine	Galaxy S9		20	https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20313_processed.png
# 20327	53808	chloroquine	Galaxy S9		20	https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20327_processed.png
# 20354	53808	chloroquine	Galaxy S9		20	https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20354_processed.png
# 20392	53808	chloroquine	iPhone 11		20	https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20392_processed.png
# 20414	53808	chloroquine	iPhone 11		20	https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20414_processed.png
# 20661	53808	chloroquine	Galaxy S9		50	https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20661_processed.png
#     <style>
#         #ipyplot-html-viewer-toggle-nYV9kCXS5qR2KdQcn7BhjX {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-nYV9kCXS5qR2KdQcn7BhjX {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-nYV9kCXS5qR2KdQcn7BhjX {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-nYV9kCXS5qR2KdQcn7BhjX:checked ~ #ipyplot-html-viewer-textarea-nYV9kCXS5qR2KdQcn7BhjX {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-nYV9kCXS5qR2KdQcn7BhjX:checked + #ipyplot-html-viewer-label-nYV9kCXS5qR2KdQcn7BhjX:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-nYV9kCXS5qR2KdQcn7BhjX">
#         <label id="ipyplot-html-viewer-label-nYV9kCXS5qR2KdQcn7BhjX" for="ipyplot-html-viewer-toggle-nYV9kCXS5qR2KdQcn7BhjX">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-nYV9kCXS5qR2KdQcn7BhjX" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-AtVLH33cnKvVqhq3f9LxC3 {
#                 display: none;
#             }
#             input.ipyplot-tab-AtVLH33cnKvVqhq3f9LxC3 + label.ipyplot-tab-label-AtVLH33cnKvVqhq3f9LxC3 {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-AtVLH33cnKvVqhq3f9LxC3:checked + label.ipyplot-tab-label-AtVLH33cnKvVqhq3f9LxC3 {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-AtVLH33cnKvVqhq3f9LxC3 ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-AtVLH33cnKvVqhq3f9LxC3 ~ .tab {
#                 display: none
#             }
#     #tabF5mXfbSgpxHX5XF5WL8XXD:checked ~ .tab.contentF5mXfbSgpxHX5XF5WL8XXD,#tabLHxDgrQb9RhpfPJnRxedaC:checked ~ .tab.contentLHxDgrQb9RhpfPJnRxedaC{ display: block; }</style><input class="ipyplot-tab-AtVLH33cnKvVqhq3f9LxC3" type="radio" name="tabs-AtVLH33cnKvVqhq3f9LxC3" id="tabF5mXfbSgpxHX5XF5WL8XXD" checked /><label class="ipyplot-tab-label-AtVLH33cnKvVqhq3f9LxC3" for="tabF5mXfbSgpxHX5XF5WL8XXD">Galaxy S9</label><input class="ipyplot-tab-AtVLH33cnKvVqhq3f9LxC3" type="radio" name="tabs-AtVLH33cnKvVqhq3f9LxC3" id="tabLHxDgrQb9RhpfPJnRxedaC"/><label class="ipyplot-tab-label-AtVLH33cnKvVqhq3f9LxC3" for="tabLHxDgrQb9RhpfPJnRxedaC">iPhone 11</label><div class="tab contentF5mXfbSgpxHX5XF5WL8XXD">
#         <style>
#         #ipyplot-imgs-container-div-VzULehkjKjUxneLU7mg4Lf {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-VzULehkjKjUxneLU7mg4Lf {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-VzULehkjKjUxneLU7mg4Lf">
#     <div class="ipyplot-placeholder-div-VzULehkjKjUxneLU7mg4Lf">
#         <div id="ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf-LGzRo3AbnrvnzmR9yEVpPU" class="ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20313_processed.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf-LGzRo3AbnrvnzmR9yEVpPU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VzULehkjKjUxneLU7mg4Lf">
#         <div id="ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf-kaVxhKwbu9EdezDPutpPDK" class="ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20327_processed.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf-kaVxhKwbu9EdezDPutpPDK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VzULehkjKjUxneLU7mg4Lf">
#         <div id="ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf-nRMFXd3JAfH7Kq8vot92Ah" class="ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20354_processed.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf-nRMFXd3JAfH7Kq8vot92Ah">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VzULehkjKjUxneLU7mg4Lf">
#         <div id="ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf-ijd2awveJrVZwTELCB9F4J" class="ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20661_processed.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VzULehkjKjUxneLU7mg4Lf-ijd2awveJrVZwTELCB9F4J">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentLHxDgrQb9RhpfPJnRxedaC">
#         <style>
# <div>
#         <style>
#             input.ipyplot-tab-AtVLH33cnKvVqhq3f9LxC3 {
#                 display: none;
#             }
#             input.ipyplot-tab-AtVLH33cnKvVqhq3f9LxC3 + label.ipyplot-tab-label-AtVLH33cnKvVqhq3f9LxC3 {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-AtVLH33cnKvVqhq3f9LxC3:checked + label.ipyplot-tab-label-AtVLH33cnKvVqhq3f9LxC3 {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-AtVLH33cnKvVqhq3f9LxC3 ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-AtVLH33cnKvVqhq3f9LxC3 ~ .tab {
#                 display: none
#             }
#     #tabF5mXfbSgpxHX5XF5WL8XXD:checked ~ .tab.contentF5mXfbSgpxHX5XF5WL8XXD,#tabLHxDgrQb9RhpfPJnRxedaC:checked ~ .tab.contentLHxDgrQb9RhpfPJnRxedaC{ display: block; }</style><input class="ipyplot-tab-AtVLH33cnKvVqhq3f9LxC3" type="radio" name="tabs-AtVLH33cnKvVqhq3f9LxC3" id="tabF5mXfbSgpxHX5XF5WL8XXD" checked /><label class="ipyplot-tab-label-AtVLH33cnKvVqhq3f9LxC
ipyplot-tab-nJSGrNuQezAEWTKpQiZ43H" type="radio" name="tabs-nJSGrNuQezAEWTKpQiZ43H" id="tabitLuYTpEBGpwLkXtguNBds" checked /><label class="ipyplot-tab-label-nJSGrNuQezAEWTKpQiZ43H" for="tabitLuYTpEBGpwLkXtguNBds">Galaxy S9</label><div class="tab contentitLuYTpEBGpwLkXtguNBds">
#         <style>
#         #ipyplot-imgs-container-div-FTqiQLTnWd4rS26WRWD5FS {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FTqiQLTnWd4rS26WRWD5FS {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-FTqiQLTnWd4rS26WRWD5FS">
#     <div class="ipyplot-placeholder-div-FTqiQLTnWd4rS26WRWD5FS">
#         <div id="ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS-7UCwDAsUzy3XS5KUNrBUqh" class="ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20465_processed.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS-7UCwDAsUzy3XS5KUNrBUqh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FTqiQLTnWd4rS26WRWD5FS">
#         <div id="ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS-o42k5VxsbA3ji6mN8dpKyq" class="ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20576_processed.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS-o42k5VxsbA3ji6mN8dpKyq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div></div>
#         </textarea>
#     </div>
# <div>
#         <style>
#             input.ipyplot-tab-nJSGrNuQezAEWTKpQiZ43H {
#                 display: none;
#             }
#             input.ipyplot-tab-nJSGrNuQezAEWTKpQiZ43H + label.ipyplot-tab-label-nJSGrNuQezAEWTKpQiZ43H {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-nJSGrNuQezAEWTKpQiZ43H:checked + label.ipyplot-tab-label-nJSGrNuQezAEWTKpQiZ43H {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-nJSGrNuQezAEWTKpQiZ43H ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-nJSGrNuQezAEWTKpQiZ43H ~ .tab {
#                 display: none
#             }
#     #tabitLuYTpEBGpwLkXtguNBds:checked ~ .tab.contentitLuYTpEBGpwLkXtguNBds{ display: block; }</style><input class="ipyplot-tab-nJSGrNuQezAEWTKpQiZ43H" type="radio" name="tabs-nJSGrNuQezAEWTKpQiZ43H" id="tabitLuYTpEBGpwLkXtguNBds" checked /><label class="ipyplot-tab-label-nJSGrNuQezAEWTKpQiZ43H" for="tabitLuYTpEBGpwLkXtguNBds">Galaxy S9</label><div class="tab contentitLuYTpEBGpwLkXtguNBds">
#         <style>
#         #ipyplot-imgs-container-div-FTqiQLTnWd4rS26WRWD5FS {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FTqiQLTnWd4rS26WRWD5FS {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-FTqiQLTnWd4rS26WRWD5FS">
#     <div class="ipyplot-placeholder-div-FTqiQLTnWd4rS26WRWD5FS">
#         <div id="ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS-7UCwDAsUzy3XS5KUNrBUqh" class="ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20465_processed.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS-7UCwDAsUzy3XS5KUNrBUqh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FTqiQLTnWd4rS26WRWD5FS">
#         <div id="ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS-o42k5VxsbA3ji6mN8dpKyq" class="ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20576_processed.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FTqiQLTnWd4rS26WRWD5FS-o42k5VxsbA3ji6mN8dpKyq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div></div>

# %%
samples_to_be_fixed=[[20503,	53816,	"chloroquine",	"iPhone 11",		50,	20,"https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20503_processed.png"],
[20661,	53808,	"chloroquine",	"Galaxy S9",		50,	20,"https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20661_processed.png"],
[20639,	53817,	"chloroquine",	"Galaxy S9",		50, 20,	"https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20639_processed.png"],
[23661,	52159,	"rifampicin",	"samsung SM-A505F",		100, 80,	"https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23661_processed.png"],
[20627,	53818,	"chloroquine",	"Galaxy S9",		50, 20,	"https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20627_processed.png"],
[23659,	52280,	"rifampicin",	"samsung SM-A505F",		100, 80,	"https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/23659_processed.png"],
[20576,	53835,	"chloroquine",	"Galaxy S9",		80, 100,	"https://pad.crc.nd.edu//var/www/html/images/padimages/processed/20000/20576_processed.png"]]

samples_to_be_fixed = pd.DataFrame(samples_to_be_fixed, columns=['id', 'sample_id', 'sample_name', 'camera_type_1', 'quantity', 'true_quantity', 'url'])
samples_to_be_fixed.to_csv('./data/FHI2020_analysis/samples_to_be_fixed.csv', index=False)

# %%
for _, sample in samples_to_be_fixed.iterrows():
    data.loc[data.id == sample.id, 'quantity'] = sample.true_quantity
    #print(sample.id, sample.true_quantity, data.loc[data.id == sample.id, 'quantity'].values[0])

# %%
# rename the files that were downloaded with incorrect name
 os.rename(tgt_folder + '20503__53816__chloroquine__50.png', tgt_folder + '20503__53816__chloroquine__20.png')
# Out:
# 3711    20
# Name: quantity, dtype: int64

# %%
os.rename(tgt_folder + '20503__53816__chloroquine__50.png', tgt_folder + '20503__53816__chloroquine__20.png')
os.rename(tgt_folder + '20661__53808__chloroquine__50.png', tgt_folder + '20661__53808__chloroquine__20.png
os.rename(tgt_folder + '20639__53817__chloroquine__50.png', tgt_folder + '20639__53817__chloroquine__20.png')
os.rename(tgt_folder + '23661__52159__rifampicin__100.png', tgt_folder + '23661__52159__rifampicin__80.png')
os.rename(tgt_folder + '20627__53818__chloroquine__50.png', tgt_folder + '20627__53818__chloroquine__20.png')
os.rename(tgt_folder + '23659__52280__rifampicin__100.png', tgt_folder + '23659__52280__rifampicin__80.png')
os.rename(tgt_folder + '20576__53835__chloroquine__80.png', tgt_folder + '20576__53835__chloroquine__100.png')

# %%
# !pwd
# Out:
# /afs/crc.nd.edu/user/p/pmoreira/pad_dataset_registry/nbs

# %% [markdown]
# ## Cleaned Data

# %% [markdown]
# On that point the dataframe `data` should have the cleaned data samples to put in the dataset.

# %%
# save cleaned dataframe to csv
data.to_csv('./data/FHI2020_analysis/cleaned_data.csv', index=False)

# %% [markdown]
# ## General Analysis

# %%
import pandas as pd
import sys
import ipyplot
sys.path.append("../src/")
from utils import *

# %%
# load no_issue_samples dataframe from csv
data = pd.read_csv('./data/FHI2020_analysis/cleaned_data.csv')

# %% [markdown]
# ### Sample names

# %%
print(data.value_counts(['sample_name']).reset_index(name='counts'))
# Out:
#                    sample_name  counts
# 0           hydroxychloroquine     821
# 1                   rifampicin     476
# 2                ciprofloxacin     455
# 3                 pyrazinamide     447
# 4                 azithromycin     438
# 5                  chloroquine     438
# 6              ferrous-sulfate     438
# 7                         ripe     427
# 8                   ethambutol     403
# 9                  ceftriaxone     387
# 10                 amoxicillin     386
# 11                tetracycline     382
# 12            sulfamethoxazole     368
# 13  promethazine-hydrochloride     351
# 14                 epinephrine     334
# 15                   isoniazid     327
# 16                 albendazole     281
# 17                 doxycycline     205
# 18                  ampicillin     186
# 19           benzyl-penicillin      94
# 20                     lactose      71
# 21              starch-(maize)      63
# 22           calcium-carbonate      60
# 23               ascorbic-acid      50

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("ticks",{'axes.grid' : True})
sns.set()
#diverging_colors = sns.color_palette("RdBu", 10)
#sns.palplot(diverging_colors)

drug_counter = data[['sample_name']].value_counts().reset_index(name='counts')
drug_quantity_counter = data[['sample_name', 'quantity']].value_counts().reset_index(name='counts')

drug_counter.sort_values(by='sample_name',  inplace=True)
drug_quantity_counter.sort_values(by=['sample_name', 'quantity'], inplace=True)
#drug_quantity_counter['sample_name'].unique().tolist() == drug_counter['sample_name'].to_list()

# %%
drug_counter.sort_values(by=['counts', 'sample_name'])
# Out:
#                    sample_name  counts
# 23               ascorbic-acid      50
# 22           calcium-carbonate      60
# 21              starch-(maize)      63
# 20                     lactose      71
# 19           benzyl-penicillin      94
# 18                  ampicillin     186
# 17                 doxycycline     205
# 16                 albendazole     281
# 15                   isoniazid     327
# 14                 epinephrine     334
# 13  promethazine-hydrochloride     351
# 12            sulfamethoxazole     368
# 11                tetracycline     382
# 10                 amoxicillin     386
# 9                  ceftriaxone     387
# 8                   ethambutol     403
# 7                         ripe     427
# 4                 azithromycin     438
# 5                  chloroquine     438
# 6              ferrous-sulfate     438
# 3                 pyrazinamide     447
# 2                ciprofloxacin     455
# 1                   rifampicin     476
# 0           hydroxychloroquine     821

# %%
# Total of samples by drug
sns.barplot(drug_counter.sort_values(by=['counts']), x='counts', y="sample_name", orient="y", alpha=0.8)
# Out:
# <Axes: xlabel='counts', ylabel='sample_name'>

# %%
sample_name_list = drug_counter.sort_values(by=['counts'])['sample_name'].to_list()

drug_quantity_counter_cat = drug_quantity_counter.copy()
drug_quantity_counter_cat['sample_name'] = pd.Categorical(drug_quantity_counter['sample_name'], sample_name_list)

sns.barplot(drug_quantity_counter_cat, x='counts', y="sample_name", orient="y", alpha=0.9)
# Out:
# <Axes: xlabel='counts', ylabel='sample_name'>

# %%
drug_quantity_counter[drug_quantity_counter['sample_name']=='benzyl-penicillin']
# Out:
#           sample_name  quantity  counts
# 81  benzyl-penicillin        20      29
# 83  benzyl-penicillin        50      12
# 80  benzyl-penicillin        80      31
# 82  benzyl-penicillin       100      22

# %%
drug_quantity_counter_cat_rev = drug_quantity_counter_cat.copy()
drug_quantity_counter_cat_rev['sample_name'] = pd.Categorical(drug_quantity_counter['sample_name'], sample_name_list[::-1])

table = drug_quantity_counter_cat_rev.pivot(index="sample_name", columns="quantity", values="counts")
fig, ax = plt.subplots(figsize=(6, 8))
sns.heatmap(table, annot=True, annot_kws={"size": 8}, fmt='g', cmap='Blues', linewidths=.3)
# Out:
# <Axes: xlabel='quantity', ylabel='sample_name'>

# %%
table.to_csv('./data/FHI2020_analysis/heatmap_drug_quantity_after_cleaning.csv')

# %%
g = sns.FacetGrid(drug_quantity_counter_cat, col="sample_name", col_wrap=4, height=4)
g.map(sns.barplot, 'quantity', "counts",  order=[20,50,80,100], alpha=0.8)

# %% [markdown]
# #### camera_type_1

# %%
data[['sample_id','sample_name','quantity', 'camera_type_1']].value_counts().reset_index(name='counts')
# Out:
#       sample_id         sample_name  quantity      camera_type_1  counts
# 0         53000  hydroxychloroquine        20          Galaxy S9      23
# 1         51730  hydroxychloroquine        20          Galaxy S9      19
# 2         53006  hydroxychloroquine        20          Galaxy S9      18
# 3         51727  hydroxychloroquine        20          Galaxy S9      17
# 4         53004  hydroxychloroquine        20          Galaxy S9      13
# ...         ...                 ...       ...                ...     ...
# 4074      53448         amoxicillin        20      BLU BLU R1 HD       1
# 4075      53444         chloroquine       100          Galaxy S9       1
# 4076      53440         chloroquine       100          Galaxy S9       1
# 4077      53439         chloroquine        80      BLU BLU R1 HD       1
# 4078      57643         amoxicillin       100  samsung SM-G770U1       1
#
# [4079 rows x 5 columns]

# %%
camera_counter = data[['camera_type_1']].value_counts().reset_index(name='counts')
camera_counter
# Out:
#           camera_type_1  counts
# 0      samsung SM-A505F    3103
# 1  HMD Global Nokia 2.3    1803
# 2       Google Pixel 3a    1288
# 3             Galaxy S9     771
# 4     Heather Iphone XS     302
# 5         BLU BLU R1 HD     250
# 6             iPhone 11     201
# 7         Kat Galaxy S9     110
# 8        Jessica Galaxy      56
# 9     samsung SM-G770U1       4

# %%
# Total of samples by drug
sns.barplot(camera_counter.sort_values(by=['counts']), x='counts', y="camera_type_1", orient="y", alpha=0.8)
# Out:
# <Axes: xlabel='counts', ylabel='camera_type_1'>

# %%
camera_quantity_counter = data[['camera_type_1', 'sample_name']].value_counts().reset_index(name='counts')
camera_quantity_counter_cat_rev = camera_quantity_counter.copy()
camera_quantity_counter_cat_rev['sample_name'] = pd.Categorical(camera_quantity_counter['sample_name'], sample_name_list[::-1])

# plot heatmap
table = camera_quantity_counter_cat_rev.pivot(index="camera_type_1", columns="sample_name", values="counts")
fig, ax = plt.subplots(figsize=(12, 4))
sns.heatmap(table, annot=True, annot_kws={"size": 8}, fmt='g', cmap='Blues', linewidths=.3)
# Out:
# <Axes: xlabel='sample_name', ylabel='camera_type_1'>

# %% [markdown]
# ### Single samples
#
# Here, I am disregarding whether the same PAD was photographed several times.

# %% [markdown]
# #### total of unique samples per `sample_name` (class/category)

# %%
samples_unique = data[['sample_id','sample_name']].value_counts().reset_index(name='counts')
print(f"Total of Unique samples {samples_unique.shape[0]}")

samples_unique_grp = samples_unique.groupby(['sample_name']).size().reset_index(name='counts')
unique_class_counter = samples_unique_grp.sort_values(by=['counts'], ascending=False).reset_index(drop=True)
print(f"{unique_class_counter['sample_name'].to_list()}")
# Out:
# Total of Unique samples 2244
# ['rifampicin', 'sulfamethoxazole', 'ciprofloxacin', 'doxycycline', 'chloroquine', 'isoniazid', 'azithromycin', 'ferrous-sulfate', 'pyrazinamide', 'amoxicillin', 'albendazole', 'ceftriaxone', 'ampicillin', 'ripe', 'hydroxychloroquine', 'ethambutol', 'tetracycline', 'promethazine-hydrochloride', 'epinephrine', 'benzyl-penicillin', 'lactose', 'calcium-carbonate', 'starch-(maize)', 'ascorbic-acid']

# %%
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="darkgrid")

fig, ax = plt.subplots(figsize=(6, 8))
sns.histplot(data=samples_unique_grp.sort_values(by=['counts']), x="counts",  y="sample_name",  alpha=0.5, linewidths=.8)
plt.show()

fig, ax = plt.subplots(figsize=(6, 8))
sns.barplot(samples_unique_grp.sort_values(by=['counts']), x='counts', y="sample_name", orient="y", alpha=0.6)
plt.show()

# %%
samples_unique = data[['sample_id','sample_name','quantity']].value_counts().reset_index(name='counts')

# %%
df1 = samples_unique[['sample_name','quantity']].value_counts().reset_index(name='counts')
df1
# Out:
#           sample_name  quantity  counts
# 0    sulfamethoxazole        50      38
# 1          ampicillin       100      37
# 2         chloroquine       100      32
# 3         albendazole       100      32
# 4          rifampicin        80      32
# ..                ...       ...     ...
# 79         ampicillin        50      22
# 80  benzyl-penicillin        20      12
# 81  benzyl-penicillin        80      11
# 82  benzyl-penicillin       100      10
# 83  benzyl-penicillin        50       6
#
# [84 rows x 3 columns]

# %%
df2 = data[['sample_name','quantity']].value_counts().reset_index(name='counts')
df2
# Out:
#            sample_name  quantity  counts
# 0   hydroxychloroquine        20     281
# 1   hydroxychloroquine        80     194
# 2   hydroxychloroquine        50     189
# 3   hydroxychloroquine       100     157
# 4          chloroquine        20     134
# ..                 ...       ...     ...
# 79          ampicillin        80      39
# 80   benzyl-penicillin        80      31
# 81   benzyl-penicillin        20      29
# 82   benzyl-penicillin       100      22
# 83   benzyl-penicillin        50      12
#
# [84 rows x 3 columns]

# %%
df1.loc[df1.sample_name == 'hydroxychloroquine']
# Out:
#            sample_name  quantity  counts
# 37  hydroxychloroquine        80      27
# 38  hydroxychloroquine       100      27
# 42  hydroxychloroquine        20      27
# 49  hydroxychloroquine        50      27

# %%
df2.loc[df2.sample_name == 'hydroxychloroquine']
# Out:
#           sample_name  quantity  counts
# 0  hydroxychloroquine        20     281
# 1  hydroxychloroquine        80     194
# 2  hydroxychloroquine        50     189
# 3  hydroxychloroquine       100     157

# %% [markdown]
# NOTE: *`df1`* gives counts by **unique sample_id** and *`df2`* gives counts considering  **duplicated sample_id** (the total of picutures)

# %%
rows = "sample_name"
cols = "quantity"
values = "counts"
rows_order = unique_class_counter['sample_name'].to_list()

show_heatmap(df1, rows, cols, values, rows_order)
show_heatmap(df2, rows, cols, values, rows_order)

# %% [markdown]
# ## Split the dataset in development and test sets

# %% [markdown]
# Note: I removed the samples that are disctractors from the dataset.

# %%
def show_heatmap_tables(table1, table2, save_name=None, figsize=(18, 8),
                        caption="Your main caption here", title1="Table 1", title2="Table 2", cmap='Blues'):
    plt.rcParams["figure.autolayout"] = True
    fig, axes = plt.subplots(1, 2, figsize=figsize)

    sns.heatmap(table1, annot=True, annot_kws={"size": 9}, fmt='g', cmap=cmap, linewidths=.4, ax=axes[0])
    axes[0].set_title(title1)  # Title for the first heatmap

    sns.heatmap(table2, annot=True, annot_kws={"size": 9}, fmt='g', cmap=cmap, linewidths=.4, ax=axes[1])
    axes[1].set_title(title2)  # Title for the second heatmap

    plt.suptitle(caption)  # Main caption/title for the figure

    plt.show()
    
    if save_name: 
        fig.savefig(save_name, bbox_inches='tight')

# %%
# remove distractores
distractors = ['lactose', 'calcium-carbonate', 'starch-(maize)', 'ascorbic-acid']
data = data.loc[~data.sample_name.isin(distractors)]
data.reset_index(drop=True, inplace=True)

print(f"Total of images {len(data)}")
# Out:
# Total of images 7644

# %% [markdown]
# data before splitting

# %%
def show_heatmap(df, rows, cols, values, rows_order = None, save_name= None, figsize=(6, 6)):
    import pandas as pd 
    import matplotlib.pyplot as plt
    import seaborn as sns
    
    df_cat = df.copy()
    df_cat[rows] = pd.Categorical(df[rows], rows_order)
    table = df_cat.pivot(index=rows, columns=cols, values=values)
    
    fig, _ = plt.subplots(figsize=figsize)
    sns.heatmap(table, annot=True, annot_kws={"size": 9}, fmt='g', cmap='Blues', linewidths=.4)
    plt.show()
    if save_name: fig.savefig(save_name,bbox_inches='tight')

# %%
set_df = data
samples_unique = set_df[['sample_id','sample_name','quantity']].value_counts().reset_index(name='counts')
df1 = samples_unique[['sample_name','quantity']].value_counts().reset_index(name='counts')
df2 = set_df[['sample_name','quantity']].value_counts().reset_index(name='counts')

rows = "sample_name"
cols = "quantity"
values = "counts"
caption = f"All data"
title1="Image counter" 
title2="Card counter" 
cmap = "Greys"
rows_order = unique_class_counter['sample_name'].to_list()

table1 = get_heatmap_table(df1, rows, cols, values, rows_order)
table2 = get_heatmap_table(df2, rows, cols, values, rows_order)
show_heatmap_tables(table2, table1, save_name= f"../datasets/FHI2020_Stratified_Sampling/report/all_data.png", 
                    figsize=(12, 6), caption=caption, title1=title1, title2=title2, cmap=cmap)

# %%
sample_names = data.sample_name.unique()
quantities = data.quantity.unique()

# %%
splits = [{'test_size': 0.10, 'cmap': "RdPu"},
          {'test_size': 0.15, 'cmap': "Purples"}, 
          {'test_size': 0.20, 'cmap': "Blues"}, 
          {'test_size': 0.25, 'cmap': "YlOrBr"},
          {'test_size': 0.30, 'cmap': "YlGn"},]

split_id=4

# %%
from sklearn.model_selection import GroupShuffleSplit

# Parameters of the splitting 
random_state = 42
test_size = splits[split_id]['test_size']
dev_size = 1 - test_size

# Parameters of the plots
cmap=splits[split_id]['cmap']
title1="Image counter" 
title2="Card counter" 
str_split = f" [Dev {int(dev_size*100)}% | Test {int(test_size*100)}%]" 

# Initialize the splitter
splitter = GroupShuffleSplit(test_size=test_size, n_splits=1, random_state=random_state)

# I'll split based on 'sample_id' to ensure images of the same card stay together
# Assuming 'group' here would represent the combined 'sample_name' and 'quantity' for stratification
all_train_idx = []
all_test_idx = []
for sample_name in sample_names:
    for quantity in quantities:
        #print(f"\n{sample_name}\t{quantity}")
        subset = data[(data['sample_name'] == sample_name) & (data['quantity'] == quantity)]
        
        # Perform the split
        for train_idx, test_idx in splitter.split(subset, groups=subset['sample_id']):
            train_subset = subset.iloc[train_idx]
            test_subset = subset.iloc[test_idx]

            # append these subsets to the overall training and testing set indexes
            all_train_idx += train_subset.index.tolist()
            all_test_idx += test_subset.index.tolist()
            #print(f"train {len(train_idx)} test {len(test_idx)}")
            
test_df = data.iloc[all_test_idx].copy()
train_val_df = data.iloc[all_train_idx].copy()

# %%
len(test_df), len(train_val_df), len(test_df) + len(train_val_df)
# Out:
# (2419, 5225, 7644)

# %% [markdown]
# #### `test_df`

# %%
set_df = test_df
samples_unique = set_df[['sample_id','sample_name','quantity']].value_counts().reset_index(name='counts')
df1 = samples_unique[['sample_name','quantity']].value_counts().reset_index(name='counts')
df2 = set_df[['sample_name','quantity']].value_counts().reset_index(name='counts')

rows = "sample_name"
cols = "quantity"
values = "counts"
caption = f"Test Tables, split={str_split}"
rows_order = unique_class_counter['sample_name'].to_list()

table1 = get_heatmap_table(df1, rows, cols, values, rows_order)
table2 = get_heatmap_table(df2, rows, cols, values, rows_order)
show_heatmap_tables(table2, table1, save_name= f"../datasets/FHI2020_Stratified_Sampling/report/test__tsize_{str(int(test_size*100))}.png", 
                    figsize=(12, 6), caption=caption, title1=title1, title2=title2, cmap=cmap)

# %% [markdown]
# #### `train_val_df`

# %%
set_df = train_val_df
samples_unique = set_df[['sample_id','sample_name','quantity']].value_counts().reset_index(name='counts')
df1 = samples_unique[['sample_name','quantity']].value_counts().reset_index(name='counts')
df2 = set_df[['sample_name','quantity']].value_counts().reset_index(name='counts')

rows = "sample_name"
cols = "quantity"
values = "counts"
caption = f"Dev Tables, split={str_split}"
rows_order = unique_class_counter['sample_name'].to_list()

table1 = get_heatmap_table(df1, rows, cols, values, rows_order)
table2 = get_heatmap_table(df2, rows, cols, values, rows_order)
show_heatmap_tables(table2, table1, save_name= f"../datasets/FHI2020_Stratified_Sampling/report/dev__tsize_{str(int(test_size*100))}.png",
                    figsize=(12, 6), caption=caption, title1=title1, title2=title2, cmap=cmap) 

# show heatmap separately
#show_heatmap(df1, rows, cols, values, rows_order)

# %% [markdown]
# #### Camera type distribution

# %%
camera_counter = data[['camera_type_1']].value_counts().reset_index(name='counts')
camera_counter.sort_values(by=['counts'], inplace=True)
camera_counter

# Total of samples by camera type
sns.barplot(camera_counter, x='counts', y="camera_type_1", orient="y", alpha=0.8)
# Out:
# <Axes: xlabel='counts', ylabel='camera_type_1'>

# %%
camera_quantity_counter = data[['camera_type_1', 'sample_name']].value_counts().reset_index(name='counts')
camera_quantity_counter_cat_rev = camera_quantity_counter.copy()
camera_quantity_counter_cat_rev['sample_name'] = pd.Categorical(camera_quantity_counter['sample_name']) #, sample_name_list[::-1])

# plot heatmap
table = camera_quantity_counter_cat_rev.pivot(index="camera_type_1", columns="sample_name", values="counts")
fig, ax = plt.subplots(figsize=(9, 5))
sns.heatmap(table, annot=True, annot_kws={"size": 8}, fmt='g', cmap='Blues', linewidths=.3)

fig.savefig("../datasets/FHI2020_Stratified_Sampling/report/camera_drug_heatmap.png", bbox_inches='tight')

# %% [markdown]
# #### check if the sets don't have intersections in terms of sample_id

# %%
# Size of sets considering all images
print(f"# Size of sets considering all images")
print(f" - train_val: {len(train_val_df)}")
print(f" - test: {len(test_df)}")
print(f" - total: {len(data)}")
print()

# Size of sets considering unique sample_ids
print(f"# Size of sets considering unique sample_ids")
print(f" - train_val: {len(train_val_df.groupby(['sample_id']))}")
print(f" - test: {len(test_df.groupby(['sample_id']))}")
print(f" - total: {len(data.groupby(['sample_id']))}")
print()
# Out:
# # Size of sets considering all images
#  - train_val: 6778
#  - test: 866
#  - total: 7644
#
# # Size of sets considering unique sample_ids
#  - train_val: 1901
#  - test: 246
#  - total: 2144

# %%
ids_test = test_df.loc[(test_df.sample_name == 'benzyl-penicillin') & (test_df.quantity == 20), 'sample_id']
ids_trainval = train_val_df.loc[(train_val_df.sample_name == 'benzyl-penicillin') & (train_val_df.quantity == 20), 'sample_id']

pd.Series(list(set(ids_trainval).intersection(set(ids_test))))
# Out:
# /tmp/ipykernel_53416/962289832.py:4: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   pd.Series(list(set(ids_trainval).intersection(set(ids_test))))
# Series([], dtype: float64)

# %% [markdown]
# - Save dataframes for test and dev sets in csv files

# %%
# create a column for image file names in both dataframes 
test_df['image_name'] = test_df.apply(lambda x: create_filename(x), axis=1)
train_val_df['image_name'] = train_val_df.apply(lambda x: create_filename(x), axis=1)

# columns to be saved
column_name_list = ['id','sample_id', 'sample_name', 'quantity', 'camera_type_1', 'url', 'hashlib_md5', 'image_name'] 

# save to csv
test_df[column_name_list].to_csv('../datasets/FHI2020_Stratified_Sampling/test_set.csv', index=False)
train_val_df[column_name_list].to_csv('../datasets/FHI2020_Stratified_Sampling/dev_set.csv', index=False)

# %% [markdown]
# -

# %%
# !dvc

# %% [markdown]
# ## Save metadata

# %% [markdown]
# - checking any left duplicates

# %%
_ = check_duplicates_by_hash(data)
# Out:
# There is no duplicates.

# %% [markdown]
# ### Set Dataset GENRAL metadata

# %%
dataset_name = 'FHI2020_Stratified_Sampling'
dataset_description = """This dataset is based on data from Project FHI2020 and comprises images from PADs, each representing a specific API from a predefined list of 20 APIs and one of four possible quantities (20, 50, 80, 100). The dataset features multiple images of the same PAD, captured under varying illumination conditions and using different devices, each image uniquely identified by an image_id, while cards share a sample_id. To address the challenge posed by its unbalanced nature regarding API names and quantities, a stratified sampling approach was employed for data splitting. Specifically, the dataset was divided such that for each API, and within each quantity category of that API, 10% of the PADs(considering all their photographs) were allocated to the test set, ensuring a proportional representation across both developing and testing subsets. This method not only maintains the balance of API types and quantities but also ensures that all photographs of the same PAD are kept together, either in the developing or the test set, to prevent data leakage and promote model generalizability.There are no distractors included in this dataset."""
dev_size = 1 - test_size
random_state = 42
hash_type = 'hashlib_md5'

# %% [markdown]
# ### Save metadata to the yaml file

# %%
import pandas as pd
import yaml

# Iterate through each row in the dataframe and add pad information to metadata
def add_pad_info_to_metadata(dataframe, metadata, dataset_name):
    for index, row in dataframe.iterrows():
        pad_info = {
            'id': row['id'],
            'sample_id': row['sample_id'],
            'sample_name': row['sample_name'],
            'quantity': row['quantity'],            
            'filename': create_filename(row),
            'image_hash': row[hash_type],
            'image_source': row['url']
        }
        metadata[dataset_name].append(pad_info)

metadata = {
    'name': dataset_name,
    'description': dataset_description,
    'creation':  get_iso8601_datetime(),
    'split': {  # Save information about the dataset splitting in development and test sets
        'dev_size': dev_size,        
        'random_seed': random_state
    },
    'hash_type': hash_type,
    'dev_set': [], # train_val_df
    'test_set': [] # test_df
}

# Create a path for that dataset
dataset_path = os.path.join( "../datasets/", dataset_name) 
os.makedirs(dataset_path, exist_ok=True)

# add metadata for each subset
add_pad_info_to_metadata(train_val_df, metadata, 'dev_set')
add_pad_info_to_metadata(test_df, metadata, 'test_set')

# Convert the metadata dictionary to YAML format
yaml_output = yaml.dump(metadata, sort_keys=False)

# Save the YAML data to a file
fpath = os.path.join(dataset_path, "metadata.yaml")
with open(fpath, 'w') as yaml_file:
    yaml_file.write(yaml_output)

print("Metadata file 'metadata.yaml' has been created.")
# Out:
# Metadata file 'metadata.yaml' has been created.

# %% [markdown]
# - [TODO] Savei nfo about the dataset and statistics with the plots
# - [TODO] Clean this notebook to share
